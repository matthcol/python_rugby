# %% [markdown]
# # Classements Rugby analysés avec Pandas
#
# source de données: csv, excel, json, xml, base de données SQL, ...

# %%
import pandas as pd

# %%
# pd.read_csv('C:\\Users\\Matthias\\Documents\\Formations\\Python\\Stage202302_R\\classements_3niveaux.csv')
# pd.read_csv('C:/Users/Matthias/Documents/Formations/Python/Stage202302_R/classements_3niveaux.csv')
dfClassements = pd.read_csv('classements_3niveaux.csv')
dfClassements
# Out:
#     Rang                                             Equipe  Pts   J   G  N  \
# 0      1                                   Stade Toulousain   63  19  13  1
# 1      2                               Stade Français Paris   55  19  11  1
# 2      3                                          LOU Rugby   53  19  12  0
# 3      4                                    Stade Rochelais   52  19  11  0
# 4      5                                   Aviron Bayonnais   50  19  11  1
# 5      6                              Union Bordeaux-Bègles   49  19  10  1
# 6      7                                          Racing 92   46  19  10  1
# 7      8                                          RC Toulon   43  19  10  0
# 8      9                                       ASM Clermont   40  19   8  1
# 9     10                          Montpellier Hérault Rugby   39  19   8  0
# 10    11                                  Castres Olympique   32  19   7  1
# ...

# %%
# Accès à une colonne

# dfClassements.Pts
dfClassements['Pts']
# Out:
# 0     63
# 1     55
# 2     53
# 3     52
# 4     50
# 5     49
# 6     46
# 7     43
# 8     40
# 9     39
# 10    32
# 11    32
# 12    30
# 13    26
# 14    83
# 15    60
# 16    59
# 17    58
# 18    57
# 19    55
# 20    52
# 21    50
# 22    50
# 23    47
# 24    47
# 25    44
# 26    37
# 27    37
# 28    36
# 29    29
# 30    80
# 31    65
# 32    62
# 33    60
# 34    59
# 35    55
# 36    54
# 37    48
# 38    48
# 39    43
# 40    39
# 41    34
# 42    23
# 43     9
# Name: Pts, dtype: int64

# %%
# opération mathématique avec un scalaire : * 2,  + 3,  / 4, - 3,  **2 (carré) 

dfClassements.Pts * 2
# Out:
# 0     126
# 1     110
# 2     106
# 3     104
# 4     100
# 5      98
# 6      92
# 7      86
# 8      80
# 9      78
# 10     64
# 11     64
# 12     60
# 13     52
# 14    166
# 15    120
# 16    118
# 17    116
# 18    114
# 19    110
# 20    104
# 21    100
# 22    100
# 23     94
# 24     94
# 25     88
# 26     74
# 27     74
# 28     72
# 29     58
# 30    160
# 31    130
# 32    124
# 33    120
# 34    118
# 35    110
# 36    108
# 37     96
# 38     96
# 39     86
# 40     78
# 41     68
# 42     46
# 43     18
# Name: Pts, dtype: int64

# %%
dfClassements['PtsMoyen'] = dfClassements.Pts / dfClassements.J
dfClassements
# Out:
#     Rang                                             Equipe  Pts   J   G  N  \
# 0      1                                   Stade Toulousain   63  19  13  1
# 1      2                               Stade Français Paris   55  19  11  1
# 2      3                                          LOU Rugby   53  19  12  0
# 3      4                                    Stade Rochelais   52  19  11  0
# 4      5                                   Aviron Bayonnais   50  19  11  1
# 5      6                              Union Bordeaux-Bègles   49  19  10  1
# 6      7                                          Racing 92   46  19  10  1
# 7      8                                          RC Toulon   43  19  10  0
# 8      9                                       ASM Clermont   40  19   8  1
# 9     10                          Montpellier Hérault Rugby   39  19   8  0
# 10    11                                  Castres Olympique   32  19   7  1
# ...

# %%
dfClassements.PtsMoyen
# Out:
# 0     3.315789
# 1     2.894737
# 2     2.789474
# 3     2.736842
# 4     2.631579
# 5     2.578947
# 6     2.421053
# 7     2.263158
# 8     2.105263
# 9     2.052632
# 10    1.684211
# 11    1.684211
# 12    1.578947
# 13    1.368421
# 14    3.772727
# 15    2.727273
# 16    2.809524
# 17    2.636364
# 18    2.590909
# 19    2.500000
# 20    2.363636
# 21    2.272727
# 22    2.272727
# 23    2.136364
# 24    2.238095
# 25    2.000000
# 26    1.681818
# 27    1.681818
# 28    1.636364
# 29    1.318182
# 30    4.210526
# 31    3.421053
# 32    3.263158
# 33    3.157895
# 34    3.105263
# 35    2.894737
# 36    2.842105
# 37    2.526316
# 38    2.526316
# 39    2.263158
# 40    2.052632
# 41    1.789474
# 42    1.210526
# 43    0.473684
# Name: PtsMoyen, dtype: float64

# %%
# Sauver les données modifiées

dfClassements.to_csv('classements_3niveaux_enrichi.csv')

# %%
dfClassements.to_csv('classements_3niveaux_enrichi_FR.csv', sep=';', decimal=',')
